# %%
# !pip install music21
# Out:
# Requirement already satisfied (use --upgrade to upgrade): music21 in /Users/gpascale/anaconda/envs/jupyterEnv/lib/python2.7/site-packages

# %%
import os
import music21
from music21.note import Note
from music21.chord import Chord
from music21.pitch import Pitch
from music21 import scale
from music21 import converter
from music21.stream import Measure, Part
from IPython.core.display import Image
from IPython.display import display
# %load_ext music21.ipython21

def show(x):
    img = Image(x.write('lily.png'))
    display(img)

# %%
def isInScale(pitch, scale):
    return True if len(scale.getPitches(pitch, pitch)) > 0 else False

def startingPitchForScale(currentPitch, scale):
    direction = 'ascending' if ascending else 'descending'
    return currentPitch if isInScale(currentPitch, s) else s.next(currentPitch, stepSize=1, direction=direction)

def readMusicXml(filename):
    testChartsPath = '../test/charts/'
    chartName = 'StellaByStarlight.xml'
    score = converter.parseFile(os.path.join(testChartsPath, filename))
    music21.harmony.realizeChordSymbolDurations(score)
    return score

def removeNotesFromScore(score):
    measures = score.parts[0].getElementsByClass('Measure')
    for measure in measures:
        measure.removeByClass('Note')

# %%
n1 = Note('e4')
n1.duration.type = 'whole'
n2 = Note('d4')
n2.duration.type = 'whole'
m1 = Measure()
m2 = Measure()
m1.append(n1)
m2.append(n2)
partLower = Part()
partLower.append(m1)
partLower.append(m2)
show(partLower)
# Out:
# <class 'music21.converter.subConverters.ConverterLilypond'>
# <music21.stream.Measure 0 offset=0.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.note.Note E>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 0 offset=4.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.note.Note D>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')

# %%
scales = [ scale.MelodicMinorScale('C'), scale.LocrianScale('D'), scale.MixolydianScale('G') ] 
part = Part()

ascending = True
currentPitch = Pitch('C4')
for s in scales:
    direction = 'ascending' if ascending else 'descending'
    currentPitch = currentPitch if isInScale(currentPitch, s) else s.next(currentPitch, stepSize=1, direction=direction)
    part.append(Note(currentPitch))
    for i in range(0, 3):
        currentPitch = s.next(currentPitch, direction=direction)
        part.append(Note(currentPitch))
    ascending = not ascending
    
show(part)
# Out:
# <class 'music21.converter.subConverters.ConverterLilypond'>
# <music21.note.Note C>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note D>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note E->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note F>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note F>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note E->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note D>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note C>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note C>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note D>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note E>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note F>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')

# %%
scale.MajorScale('E-').getPitches('E4', 'A-4')
# Out:
# [<music21.pitch.Pitch F4>, <music21.pitch.Pitch G4>, <music21.pitch.Pitch A-4>]

# %%
# Can notes be put directly into a stream?
part = Part()
majorScale = scale.MajorScale('C')
pitches = majorScale.getPitches()
for pitch in pitches:
    part.append(Note(pitch))
display(type(part))
show(part)
# Out:
# music21.stream.Part
# <class 'music21.converter.subConverters.ConverterLilypond'>
# <music21.note.Note C>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note D>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note E>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note F>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note G>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note A>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note C>
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')

# %%
# Import MusicXML
reload(music21)
testChartsPath = '../test/charts/'
chartName = 'StellaByStarlight.xml'
score = converter.parseFile(os.path.join(testChartsPath, chartName))
music21.harmony.realizeChordSymbolDurations(score)
part = score.parts[0]
measures = part.getElementsByClass('Measure')



# show(score, 'text')
# score.show('oldmusicxml')
# show(score)
# xml = music21.musicxml.m21ToXml.GeneralObjectExporter().parse(score)
# xml
# with open('StellaOut.xml', 'w') as f:
#     f.write(xml)
score.show('text')
show(score)
# Out:
# {0.0} <music21.metadata.Metadata object at 0x109ed3190>
# {0.0} <music21.stream.Part Lead sheet>
#     {0.0} <music21.instrument.Instrument P1: Lead sheet: >
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.bar.Barline style=double>
#         {0.0} <music21.clef.TrebleClef>
#         {0.0} <music21.key.Key of B- major>
#         {0.0} <music21.meter.TimeSignature 4/4>
#         {0.0} <music21.harmony.ChordSymbol Em7 alter b5>
#         {0.0} <music21.note.Note B->
#     {4.0} <music21.stream.Measure 2 offset=4.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol A7 add b9>
#         {0.0} <music21.note.Note B->
#     {8.0} <music21.stream.Measure 3 offset=8.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol Cm7>
#         {0.0} <music21.note.Note B->
#     {12.0} <music21.stream.Measure 4 offset=12.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol F7>
#         {0.0} <music21.note.Note B->
#     {16.0} <music21.stream.Measure 5 offset=16.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol Fm7>
#         {0.0} <music21.note.Note B->
#     {20.0} <music21.stream.Measure 6 offset=20.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol B-7>
#         {0.0} <music21.note.Note B->
#     {24.0} <music21.stream.Measure 7 offset=24.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol E-maj7>
#         {0.0} <music21.note.Note B->
#     {28.0} <music21.stream.Measure 8 offset=28.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol A-7>
#         {0.0} <music21.note.Note B->
#     {32.0} <music21.stream.Measure 9 offset=32.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol B-maj7>
#         {0.0} <music21.note.Note B->
#     {36.0} <music21.stream.Measure 10 offset=36.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol Em7 alter b5>
#         {0.0} <music21.note.Note B->
#         {2.0} <music21.harmony.ChordSymbol A7 add b9>
#         {2.0} <music21.note.Note B->
#     {40.0} <music21.stream.Measure 11 offset=40.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol Dm7>
#         {0.0} <music21.note.Note B->
#     {44.0} <music21.stream.Measure 12 offset=44.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol B-m7>
#         {0.0} <music21.note.Note B->
#         {2.0} <music21.harmony.ChordSymbol E-7>
#         {2.0} <music21.note.Note B->
#     {48.0} <music21.stream.Measure 13 offset=48.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol Fmaj7>
#         {0.0} <music21.note.Note B->
#     {52.0} <music21.stream.Measure 14 offset=52.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol Em7 alter b5>
#         {0.0} <music21.note.Note B->
#     {56.0} <music21.stream.Measure 15 offset=56.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol E-maj7 add #11>
#         {0.0} <music21.note.Note B->
#     {60.0} <music21.stream.Measure 16 offset=60.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol D7 add b9>
#         {0.0} <music21.note.Note B->
#         {4.0} <music21.bar.Barline style=double>
#     {64.0} <music21.stream.Measure 17 offset=64.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.bar.Barline style=double>
#         {0.0} <music21.harmony.ChordSymbol G7 add b13>
#         {0.0} <music21.note.Note B->
#     {68.0} <music21.stream.Measure 18 offset=68.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol G7 add b13>
#         {0.0} <music21.note.Note B->
#     {72.0} <music21.stream.Measure 19 offset=72.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol Cm7>
#         {0.0} <music21.note.Note B->
#     {76.0} <music21.stream.Measure 20 offset=76.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol Cm7>
#         {0.0} <music21.note.Note B->
#     {80.0} <music21.stream.Measure 21 offset=80.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol A-7 add #11>
#         {0.0} <music21.note.Note B->
#     {84.0} <music21.stream.Measure 22 offset=84.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol A-7 add #11>
#         {0.0} <music21.note.Note B->
#     {88.0} <music21.stream.Measure 23 offset=88.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol B-maj7>
#         {0.0} <music21.note.Note B->
#     {92.0} <music21.stream.Measure 24 offset=92.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol B-maj7>
#         {0.0} <music21.note.Note B->
#         {4.0} <music21.bar.Barline style=double>
#     {96.0} <music21.stream.Measure 25 offset=96.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.bar.Barline style=double>
#         {0.0} <music21.harmony.ChordSymbol Em7 alter b5>
#         {0.0} <music21.note.Note B->
#     {100.0} <music21.stream.Measure 26 offset=100.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol A7 add b9>
#         {0.0} <music21.note.Note B->
#     {104.0} <music21.stream.Measure 27 offset=104.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol Dm7 alter b5>
#         {0.0} <music21.note.Note B->
#     {108.0} <music21.stream.Measure 28 offset=108.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol G7 add b9>
#         {0.0} <music21.note.Note B->
#     {112.0} <music21.stream.Measure 29 offset=112.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol Cm7 alter b5>
#         {0.0} <music21.note.Note B->
#     {116.0} <music21.stream.Measure 30 offset=116.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol F7 add b9>
#         {0.0} <music21.note.Note B->
#     {120.0} <music21.stream.Measure 31 offset=120.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol B-maj7>
#         {0.0} <music21.note.Note B->
#     {124.0} <music21.stream.Measure 32 offset=124.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol B-maj7>
#         {0.0} <music21.note.Note B->
#         {4.0} <music21.bar.Barline style=final>
# {0.0} <music21.layout.ScoreLayout>
# <class 'music21.converter.subConverters.ConverterLilypond'>
# P1: Lead sheet:
# ('Instrument', 'Music21Object', 'object')
# <music21.stream.Measure 1 offset=0.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.bar.Barline style=double>
# ('Barline', 'Music21Object', 'object')
# <music21.clef.TrebleClef>
# ('TrebleClef', 'GClef', 'PitchClef', 'Clef', 'Music21Object', 'object')
# B- major
# ('Key', 'KeySignature', 'DiatonicScale', 'ConcreteScale', 'Scale', 'Music21Object', 'object')
# <music21.meter.TimeSignature 4/4>
# ('TimeSignature', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Em7 alter b5>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 2 offset=4.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol A7 add b9>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 3 offset=8.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Cm7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 4 offset=12.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol F7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 5 offset=16.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Fm7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 6 offset=20.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol B-7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 7 offset=24.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol E-maj7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 8 offset=28.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol A-7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 9 offset=32.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol B-maj7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 10 offset=36.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Em7 alter b5>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol A7 add b9>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 11 offset=40.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Dm7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 12 offset=44.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol B-m7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol E-7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 13 offset=48.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Fmaj7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 14 offset=52.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Em7 alter b5>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 15 offset=56.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol E-maj7 add #11>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 16 offset=60.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol D7 add b9>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.bar.Barline style=double>
# ('Barline', 'Music21Object', 'object')
# <music21.stream.Measure 17 offset=64.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.bar.Barline style=double>
# ('Barline', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol G7 add b13>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 18 offset=68.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol G7 add b13>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 19 offset=72.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Cm7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 20 offset=76.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Cm7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 21 offset=80.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol A-7 add #11>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 22 offset=84.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol A-7 add #11>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 23 offset=88.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol B-maj7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 24 offset=92.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol B-maj7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.bar.Barline style=double>
# ('Barline', 'Music21Object', 'object')
# <music21.stream.Measure 25 offset=96.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.bar.Barline style=double>
# ('Barline', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Em7 alter b5>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 26 offset=100.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol A7 add b9>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 27 offset=104.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Dm7 alter b5>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 28 offset=108.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol G7 add b9>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 29 offset=112.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Cm7 alter b5>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 30 offset=116.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol F7 add b9>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 31 offset=120.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol B-maj7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 32 offset=124.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol B-maj7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.bar.Barline style=final>
# ('Barline', 'Music21Object', 'object')
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo

# %%
score = readMusicXml('StellaByStarlight.xml')
# score.remove(score.getElementsByClass('Note'))

parts = score.flat.getElementsByClass('Part')
measures = score.flat.getElementsByClass('Measure')
notes = score.flat.getElementsByClass('Note')

# removeNotesFromScore(score)
show(score)
# Out:
# <class 'music21.converter.subConverters.ConverterLilypond'>
# P1: Lead sheet:
# ('Instrument', 'Music21Object', 'object')
# <music21.stream.Measure 1 offset=0.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.bar.Barline style=double>
# ('Barline', 'Music21Object', 'object')
# <music21.clef.TrebleClef>
# ('TrebleClef', 'GClef', 'PitchClef', 'Clef', 'Music21Object', 'object')
# B- major
# ('Key', 'KeySignature', 'DiatonicScale', 'ConcreteScale', 'Scale', 'Music21Object', 'object')
# <music21.meter.TimeSignature 4/4>
# ('TimeSignature', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Em7 alter b5>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 2 offset=4.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol A7 add b9>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 3 offset=8.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Cm7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 4 offset=12.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol F7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 5 offset=16.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Fm7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 6 offset=20.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol B-7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 7 offset=24.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol E-maj7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 8 offset=28.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol A-7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 9 offset=32.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol B-maj7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 10 offset=36.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Em7 alter b5>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol A7 add b9>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 11 offset=40.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Dm7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 12 offset=44.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol B-m7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol E-7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 13 offset=48.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Fmaj7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 14 offset=52.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Em7 alter b5>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 15 offset=56.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol E-maj7 add #11>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 16 offset=60.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol D7 add b9>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.bar.Barline style=double>
# ('Barline', 'Music21Object', 'object')
# <music21.stream.Measure 17 offset=64.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.bar.Barline style=double>
# ('Barline', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol G7 add b13>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 18 offset=68.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol G7 add b13>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 19 offset=72.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Cm7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 20 offset=76.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Cm7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 21 offset=80.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol A-7 add #11>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 22 offset=84.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol A-7 add #11>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 23 offset=88.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol B-maj7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 24 offset=92.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol B-maj7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.bar.Barline style=double>
# ('Barline', 'Music21Object', 'object')
# <music21.stream.Measure 25 offset=96.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.bar.Barline style=double>
# ('Barline', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Em7 alter b5>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 26 offset=100.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol A7 add b9>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 27 offset=104.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Dm7 alter b5>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 28 offset=108.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol G7 add b9>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 29 offset=112.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol Cm7 alter b5>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 30 offset=116.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol F7 add b9>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 31 offset=120.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol B-maj7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.stream.Measure 32 offset=124.0>
# ('Measure', 'Stream', 'StreamCoreMixin', 'Music21Object', 'object')
# <music21.layout.SystemLayout>
# ('SystemLayout', 'LayoutBase', 'Music21Object', 'object')
# <music21.harmony.ChordSymbol B-maj7>
# ('ChordSymbol', 'Harmony', 'Chord', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.note.Note B->
# ('Note', 'NotRest', 'GeneralNote', 'Music21Object', 'object')
# <music21.bar.Barline style=final>
# ('Barline', 'Music21Object', 'object')
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo
# chordypoo

# %%
import music21
music21.__file__
# Out:
# '/Users/gpascale/anaconda/envs/jupyterEnv/lib/python2.7/site-packages/music21/__init__.pyc'
